# %% [markdown]
# # Display the 384 well plate

# %%
import json
import os

from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()

x_paths = ["/endpoint_outputs/Top right_xposition.json",
          "endpoint_outputs/Top left_xposition.json",
          "endpoint_outputs/Bottom left_xposition.json"]

y_paths = ["endpoint_outputs/Top right_yposition.json", "endpoint_outputs/Top left_yposition.json",
          "endpoint_outputs/Bottom left_yposition.json"]
data_path = os.getcwd()
print(data_path)
tr, tl, bl = [ [eval(json.load(open(data_path + "/" + x))["Value"]),eval(json.load(open(data_path + "/" + y))["Value"])] for x,y in zip(x_paths, y_paths) ]
r_n, c_n = 16, 24

from DragonFlyWellPlateAutomation.gui.Visualisation import setplotlimits, setticks
import matplotlib.pyplot as plt
import numpy as np


import matplotlib.pyplot as plt
import numpy as np


def create_plot(xmin=-50, 
    xmax=60,
    ymin=-40,
    ymax= 32):
    
    # All values are in mm

    fig, axis = plt.subplots(figsize=(11,7.2))


    ## Reduce scatter point to field of view size
    fov = 250*10**(-6) * 1024



    axis.set_xlim(xmin, xmax)
    axis.set_ylim(ymin, ymax)

    c_n = 24
    r_n = 16

    borders_c = c_n+1
    borders_r = r_n+1
    x_coords, xstep =np.linspace(xmin, xmax,borders_c, retstep=True)
    ycoords, ystep=np.linspace(ymin, ymax, borders_r, retstep=True)
    axis.set_xticks(x_coords, minor=True)
    axis.set_yticks(ycoords, minor=True)
        # Gridlines based on minor ticks
    axis.grid(which='minor')
    axis.tick_params(which='minor', bottom=False, left=False)




    axis.set_title('Real-Time {} well plate positioning'.format(c_n * r_n), fontsize=20)

    

    # Major ticks
    x_values=list(range(1, c_n+1))
    y_values= [x for x in "ABCDEFGHIJKLMNOPQRSTUVWXYZ"[:r_n]]
    axis.set_xticks(np.linspace(xmin+(xstep/2),xmax-(xstep/2), c_n), minor=False)
    axis.set_yticks(np.linspace(ymin+(ystep/2),ymax-(ystep/2),r_n), minor=False)
    
    # Labels for major ticks
    axis.set_xticklabels(x_values, minor=False)
    axis.set_yticklabels(reversed(y_values), minor=False)
    
    


    axis.tick_params(axis='x', labelsize='medium')

    axis.tick_params(axis='y', labelsize='medium')
    
    axis.set_aspect("equal")

    ### Get normalized length and height of axis
    # Scaling factor of y and x 
    transform = ((404.43636364-79.78181818)/72)
    well_h= 4.5
    print(transform)
    #Pixels
    well_h_pixels = (well_h * transform) 
    #Points
    p = 72/100
    print(well_h_pixels)
    #s
    s = (well_h_pixels*p)**2
    y_offset = (2/16)
    x_offset = (2/24)
    fov = 250*10**(-6) * 1024 #height
    s = (fov*p)**2

    print("x and y step: {} and {}".format(xstep, ystep))
    print("Ymin {} and Ymax {}".format(min(ycoords), max(ycoords)))
    print("Xmin {} and Xmax {}".format(min(x_coords), max(x_coords)))
    return axis
# Out:
# search for root_dir and set working directory
# Working directory set to: /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation
# /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation

# %%
print(tl)
# Out:
# [-47.7, 33.1]

# %%
print(bl)
# Out:
# [-47.7, -38.6]

# %%
# Save this as marker occuping one cell
axis.scatter(xmin + (4.5/2) + x_offset, ymax-(4.5/2)-y_offset, c="r", s=s, marker=",")

# %%
- 60 - 50 # 110 x length

-40 - 32 # 72mm x heightnp.array(

# %%
axis.transData.transform((-50, -38)) #x,y for bl

# %%
axis.transData.transform((-50, 34)) #x,y for tl

# %% [markdown]
# ## Predict coordinates of wells using 384 well plate class

# %%
import json
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from DragonFlyWellPlateAutomation.devices.wellplate import WellPlate as wp


WellPlate = wp()
WellPlate.well_plate_req_coords["Top right well"] = WellPlate.vector_2_state_dict(tr)
WellPlate.well_plate_req_coords["Top left well"] = WellPlate.vector_2_state_dict(tl)
WellPlate.well_plate_req_coords["Bottom left well"] = WellPlate.vector_2_state_dict(bl)
# Out:
# search for root_dir and set working directory
# Working directory set to: /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation
# search for root_dir and set working directory
# Working directory set to: /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation

# %% [markdown]
# ### Try 1: Publication with 4 corners

# %%
# Now visualise on coordinate plot method from publication
vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm=WellPlate.coordinate_frame_algorithms[1], algorithm_H="non-linear", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )
### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot()



for vector, wellname in zip(vectors,well_names):
    #print("Well name {} and its coordinate: {}".format(wellname, vector))
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    axis.text(x, y, wellname, ha='center', va='bottom',fontsize="xx-small")
    
plt.show()
# Out:
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Linear correction matrix
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -40.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0

# %% [markdown]
# ### Try 2: Linear spacing with 3 corners

# %%
vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Linear spacing", algorithm_H="non-linear", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot()

vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))


for vector, wellname in zip(vectors,well_names):
    #print("Well name {} and its coordinate: {}".format(wellname, vector))
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    axis.text(x, y, wellname, ha='center', va='bottom',fontsize="xx-small")
plt.show()
# Out:
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Linear spacing
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.5
# Ymin -38.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0

# %% [markdown]
# ### Try 3: Homography estimated using SVD

# %%
vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Homography", algorithm_H="SVD", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height_
s = (fov*p)**2
    
axis = create_plot()

vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
for vector in vectors:
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    
plt.show()
# Out:
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Homography
# Learning the homography matrix using SVD to map from well plate row and column arrangement to xzy-stage coordinate space
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -40.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0

# %% [markdown]
# ### Try 4: RANSAC Homography

# %%
import json
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from DragonFlyWellPlateAutomation.devices.wellplate import WellPlate as wp


WellPlate = wp()
WellPlate.well_plate_req_coords["Top right well"] = WellPlate.vector_2_state_dict(tr)
WellPlate.well_plate_req_coords["Top left well"] = WellPlate.vector_2_state_dict(tl)
WellPlate.well_plate_req_coords["Bottom left well"] = WellPlate.vector_2_state_dict(bl)

vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Homography", algorithm_H="Levenberg-Marquardt", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot()
# [ 3.2457051  -0.18143457  0.9949577 ]
vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
for vector, wellname in zip(vectors,well_names):
    print("Well name {} and its coordinate: {}".format(wellname, vector))
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    axis.text(x, y, wellname, ha='center', va='bottom',fontsize="xx-small")

plt.tight_layout()
plt.show()
# Out:
# search for root_dir and set working directory
# Working directory set to: /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Homography
# Learning the homography matrix using Levenberg-Marquardt to map from well plate row and column arrangement to xzy-stage coordinate space
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -40.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0
# Well name 1-1 and its coordinate: [-47.67996    33.08609     0.9995798]
# Well name 1-2 and its coordinate: [-43.05035     33.10231      0.99915963]
# Well name 1-3 and its coordinate: [-38.420746   33.11853     0.9987394]
# Well name 1-4 and its coordinate: [-33.79114    33.13475     0.9983192]
# Well name 1-5 and its coordinate: [-29.161535    33.150967     0.99789906]
# Well name 1-6 and its coordinate: [-24.531929    33.167187     0.99747884]
# Well name 1-7 and its coordinate: [-19.902323    33.183407     0.99705863]
# Well name 1-8 and its coordinate: [-15.272717   33.199627    0.9966385]
# Well name 1-9 and its coordinate: [-10.643112    33.215847     0.99621826]
# Well name 1-10 and its coordinate: [-6.0135064  33.232067    0.99579805]
# Well name 1-11 and its coordinate: [-1.3839006 33.248283   0.9953779]
# Well name 1-12 and its coordinate: [ 3.2457051 33.264503   0.9949577]
# Well name 1-13 and its coordinate: [ 7.875311  33.280724   0.9945375]
# Well name 1-14 and its coordinate: [12.504916   33.296944    0.99411726]
# Well name 1-15 and its coordinate: [17.134521  33.313164   0.9936971]
# Well name 1-16 and its coordinate: [21.764128  33.329384   0.9932769]
# Well name 1-17 and its coordinate: [26.393734  33.3456     0.9928567]
# Well name 1-18 and its coordinate: [31.023338  33.36182    0.9924365]
# Well name 1-19 and its coordinate: [35.652946  33.37804    0.9920163]
# Well name 1-20 and its coordinate: [40.28255   33.39426    0.9915961]
# Well name 1-21 and its coordinate: [44.912155   33.41048     0.99117595]
# Well name 1-22 and its coordinate: [49.541763   33.4267      0.99075574]
# Well name 1-23 and its coordinate: [54.171368  33.442917   0.9903355]
# Well name 1-24 and its coordinate: [58.800972  33.459137   0.9899154]
# Well name 2-1 and its coordinate: [-47.67996    28.308098    0.9995798]
# Well name 2-2 and its coordinate: [-43.05035     28.324318     0.99915963]
# Well name 2-3 and its coordinate: [-38.420746   28.340538    0.9987394]
# Well name 2-4 and its coordinate: [-33.79114    28.356758    0.9983192]
# Well name 2-5 and its coordinate: [-29.161535    28.372976     0.99789906]
# Well name 2-6 and its coordinate: [-24.531929    28.389196     0.99747884]
# Well name 2-7 and its coordinate: [-19.902323    28.405416     0.99705863]
# Well name 2-8 and its coordinate: [-15.272717   28.421635    0.9966385]
# Well name 2-9 and its coordinate: [-10.643112    28.437855     0.99621826]
# Well name 2-10 and its coordinate: [-6.0135064  28.454075    0.99579805]
# Well name 2-11 and its coordinate: [-1.3839006 28.470293   0.9953779]
# Well name 2-12 and its coordinate: [ 3.2457051 28.486513   0.9949577]
# Well name 2-13 and its coordinate: [ 7.875311  28.502733   0.9945375]
# Well name 2-14 and its coordinate: [12.504916   28.518951    0.99411726]
# Well name 2-15 and its coordinate: [17.134521  28.535172   0.9936971]
# Well name 2-16 and its coordinate: [21.764128  28.551392   0.9932769]
# Well name 2-17 and its coordinate: [26.393734  28.56761    0.9928567]
# Well name 2-18 and its coordinate: [31.023338  28.58383    0.9924365]
# Well name 2-19 and its coordinate: [35.652946  28.60005    0.9920163]
# Well name 2-20 and its coordinate: [40.28255   28.616268   0.9915961]
# Well name 2-21 and its coordinate: [44.912155   28.632488    0.99117595]
# Well name 2-22 and its coordinate: [49.541763   28.648708    0.99075574]
# Well name 2-23 and its coordinate: [54.171368  28.664927   0.9903355]
# Well name 2-24 and its coordinate: [58.800972  28.681147   0.9899154]
# Well name 3-1 and its coordinate: [-47.67996    23.530107    0.9995798]
# Well name 3-2 and its coordinate: [-43.05035     23.546328     0.99915963]
# Well name 3-3 and its coordinate: [-38.420746   23.562546    0.9987394]
# Well name 3-4 and its coordinate: [-33.79114    23.578766    0.9983192]
# Well name 3-5 and its coordinate: [-29.161535    23.594986     0.99789906]
# Well name 3-6 and its coordinate: [-24.531929    23.611204     0.99747884]
# Well name 3-7 and its coordinate: [-19.902323    23.627424     0.99705863]
# Well name 3-8 and its coordinate: [-15.272717   23.643644    0.9966385]
# Well name 3-9 and its coordinate: [-10.643112    23.659863     0.99621826]
# Well name 3-10 and its coordinate: [-6.0135064  23.676083    0.99579805]
# Well name 3-11 and its coordinate: [-1.3839006 23.692303   0.9953779]
# Well name 3-12 and its coordinate: [ 3.2457051 23.70852    0.9949577]
# Well name 3-13 and its coordinate: [ 7.875311  23.724741   0.9945375]
# Well name 3-14 and its coordinate: [12.504916   23.740961    0.99411726]
# Well name 3-15 and its coordinate: [17.134521  23.757181   0.9936971]
# Well name 3-16 and its coordinate: [21.764128  23.7734     0.9932769]
# Well name 3-17 and its coordinate: [26.393734  23.78962    0.9928567]
# Well name 3-18 and its coordinate: [31.023338  23.80584    0.9924365]
# Well name 3-19 and its coordinate: [35.652946  23.822058   0.9920163]
# Well name 3-20 and its coordinate: [40.28255   23.838278   0.9915961]
# Well name 3-21 and its coordinate: [44.912155   23.854498    0.99117595]
# Well name 3-22 and its coordinate: [49.541763   23.870716    0.99075574]
# Well name 3-23 and its coordinate: [54.171368  23.886936   0.9903355]
# Well name 3-24 and its coordinate: [58.800972  23.903156   0.9899154]
# Well name 4-1 and its coordinate: [-47.67996    18.752117    0.9995798]
# Well name 4-2 and its coordinate: [-43.05035     18.768335     0.99915963]
# Well name 4-3 and its coordinate: [-38.420746   18.784555    0.9987394]
# Well name 4-4 and its coordinate: [-33.79114    18.800776    0.9983192]
# Well name 4-5 and its coordinate: [-29.161535    18.816994     0.99789906]
# Well name 4-6 and its coordinate: [-24.531929    18.833214     0.99747884]
# Well name 4-7 and its coordinate: [-19.902323    18.849434     0.99705863]
# Well name 4-8 and its coordinate: [-15.272717   18.865652    0.9966385]
# Well name 4-9 and its coordinate: [-10.643112    18.881872     0.99621826]
# Well name 4-10 and its coordinate: [-6.0135064  18.898092    0.99579805]
# Well name 4-11 and its coordinate: [-1.3839006 18.91431    0.9953779]
# Well name 4-12 and its coordinate: [ 3.2457051 18.93053    0.9949577]
# Well name 4-13 and its coordinate: [ 7.875311  18.94675    0.9945375]
# Well name 4-14 and its coordinate: [12.504916   18.962969    0.99411726]
# Well name 4-15 and its coordinate: [17.134521  18.979189   0.9936971]
# Well name 4-16 and its coordinate: [21.764128  18.995409   0.9932769]
# Well name 4-17 and its coordinate: [26.393734  19.011627   0.9928567]
# Well name 4-18 and its coordinate: [31.023338  19.027847   0.9924365]
# Well name 4-19 and its coordinate: [35.652946  19.044067   0.9920163]
# Well name 4-20 and its coordinate: [40.28255   19.060286   0.9915961]
# Well name 4-21 and its coordinate: [44.912155   19.076506    0.99117595]
# Well name 4-22 and its coordinate: [49.541763   19.092726    0.99075574]
# Well name 4-23 and its coordinate: [54.171368  19.108944   0.9903355]
# Well name 4-24 and its coordinate: [58.800972  19.125164   0.9899154]
# Well name 5-1 and its coordinate: [-47.67996    13.974125    0.9995798]
# Well name 5-2 and its coordinate: [-43.05035     13.990344     0.99915963]
# Well name 5-3 and its coordinate: [-38.420746   14.006564    0.9987394]
# Well name 5-4 and its coordinate: [-33.79114    14.022783    0.9983192]
# Well name 5-5 and its coordinate: [-29.161535    14.039002     0.99789906]
# Well name 5-6 and its coordinate: [-24.531929    14.0552225    0.99747884]
# Well name 5-7 and its coordinate: [-19.902323    14.071442     0.99705863]
# Well name 5-8 and its coordinate: [-15.272717   14.087662    0.9966385]
# Well name 5-9 and its coordinate: [-10.643112    14.103881     0.99621826]
# Well name 5-10 and its coordinate: [-6.0135064  14.1201      0.99579805]
# Well name 5-11 and its coordinate: [-1.3839006 14.13632    0.9953779]
# Well name 5-12 and its coordinate: [ 3.2457051 14.152539   0.9949577]
# Well name 5-13 and its coordinate: [ 7.875311  14.168758   0.9945375]
# Well name 5-14 and its coordinate: [12.504916   14.1849785   0.99411726]
# Well name 5-15 and its coordinate: [17.134521  14.201198   0.9936971]
# Well name 5-16 and its coordinate: [21.764128  14.217417   0.9932769]
# Well name 5-17 and its coordinate: [26.393734  14.233637   0.9928567]
# Well name 5-18 and its coordinate: [31.023338  14.249856   0.9924365]
# Well name 5-19 and its coordinate: [35.652946  14.266075   0.9920163]
# Well name 5-20 and its coordinate: [40.28255   14.282295   0.9915961]
# Well name 5-21 and its coordinate: [44.912155   14.298514    0.99117595]
# Well name 5-22 and its coordinate: [49.541763   14.314734    0.99075574]
# Well name 5-23 and its coordinate: [54.171368  14.330954   0.9903355]
# Well name 5-24 and its coordinate: [58.800972  14.347173   0.9899154]
# Well name 6-1 and its coordinate: [-47.67996     9.196134    0.9995798]
# Well name 6-2 and its coordinate: [-43.05035      9.212353     0.99915963]
# Well name 6-3 and its coordinate: [-38.420746    9.228573    0.9987394]
# Well name 6-4 and its coordinate: [-33.79114     9.244792    0.9983192]
# Well name 6-5 and its coordinate: [-29.161535     9.261012     0.99789906]
# Well name 6-6 and its coordinate: [-24.531929     9.277231     0.99747884]
# Well name 6-7 and its coordinate: [-19.902323     9.29345      0.99705863]
# Well name 6-8 and its coordinate: [-15.272717    9.30967     0.9966385]
# Well name 6-9 and its coordinate: [-10.643112     9.32589      0.99621826]
# Well name 6-10 and its coordinate: [-6.0135064   9.342109    0.99579805]
# Well name 6-11 and its coordinate: [-1.3839006  9.358329   0.9953779]
# Well name 6-12 and its coordinate: [3.2457051 9.374548  0.9949577]
# Well name 6-13 and its coordinate: [7.875311  9.390767  0.9945375]
# Well name 6-14 and its coordinate: [12.504916    9.406987    0.99411726]
# Well name 6-15 and its coordinate: [17.134521   9.423206   0.9936971]
# Well name 6-16 and its coordinate: [21.764128   9.439425   0.9932769]
# Well name 6-17 and its coordinate: [26.393734   9.455646   0.9928567]
# Well name 6-18 and its coordinate: [31.023338   9.471865   0.9924365]
# Well name 6-19 and its coordinate: [35.652946   9.488085   0.9920163]
# Well name 6-20 and its coordinate: [40.28255    9.504304   0.9915961]
# Well name 6-21 and its coordinate: [44.912155    9.520523    0.99117595]
# Well name 6-22 and its coordinate: [49.541763    9.536743    0.99075574]
# Well name 6-23 and its coordinate: [54.171368   9.552962   0.9903355]
# Well name 6-24 and its coordinate: [58.800972   9.569181   0.9899154]
# Well name 7-1 and its coordinate: [-47.67996     4.4181423   0.9995798]
# Well name 7-2 and its coordinate: [-43.05035      4.434362     0.99915963]
# Well name 7-3 and its coordinate: [-38.420746    4.4505816   0.9987394]
# Well name 7-4 and its coordinate: [-33.79114     4.4668007   0.9983192]
# Well name 7-5 and its coordinate: [-29.161535     4.4830203    0.99789906]
# Well name 7-6 and its coordinate: [-24.531929     4.49924      0.99747884]
# Well name 7-7 and its coordinate: [-19.902323     4.5154595    0.99705863]
# Well name 7-8 and its coordinate: [-15.272717    4.5316787   0.9966385]
# Well name 7-9 and its coordinate: [-10.643112     4.5478983    0.99621826]
# Well name 7-10 and its coordinate: [-6.0135064   4.564118    0.99579805]
# Well name 7-11 and its coordinate: [-1.3839006  4.580337   0.9953779]
# Well name 7-12 and its coordinate: [3.2457051 4.5965567 0.9949577]
# Well name 7-13 and its coordinate: [7.875311  4.6127763 0.9945375]
# Well name 7-14 and its coordinate: [12.504916    4.628996    0.99411726]
# Well name 7-15 and its coordinate: [17.134521   4.645215   0.9936971]
# Well name 7-16 and its coordinate: [21.764128   4.6614347  0.9932769]
# Well name 7-17 and its coordinate: [26.393734   4.6776543  0.9928567]
# Well name 7-18 and its coordinate: [31.023338   4.6938734  0.9924365]
# Well name 7-19 and its coordinate: [35.652946   4.710093   0.9920163]
# Well name 7-20 and its coordinate: [40.28255    4.7263126  0.9915961]
# Well name 7-21 and its coordinate: [44.912155    4.742532    0.99117595]
# Well name 7-22 and its coordinate: [49.541763    4.7587514   0.99075574]
# Well name 7-23 and its coordinate: [54.171368   4.774971   0.9903355]
# Well name 7-24 and its coordinate: [58.800972   4.7911906  0.9899154]
# Well name 8-1 and its coordinate: [-47.67996     -0.35984883   0.9995798 ]
# Well name 8-2 and its coordinate: [-43.05035     -0.34362936   0.99915963]
# Well name 8-3 and its coordinate: [-38.420746    -0.32740986   0.9987394 ]
# Well name 8-4 and its coordinate: [-33.79114    -0.3111904   0.9983192]
# Well name 8-5 and its coordinate: [-29.161535    -0.29497093   0.99789906]
# Well name 8-6 and its coordinate: [-24.531929    -0.27875143   0.99747884]
# Well name 8-7 and its coordinate: [-19.902323    -0.26253197   0.99705863]
# Well name 8-8 and its coordinate: [-15.272717    -0.24631248   0.9966385 ]
# Well name 8-9 and its coordinate: [-10.643112    -0.230093     0.99621826]
# Well name 8-10 and its coordinate: [-6.0135064  -0.21387352  0.99579805]
# Well name 8-11 and its coordinate: [-1.3839006  -0.19765405  0.9953779 ]
# Well name 8-12 and its coordinate: [ 3.2457051  -0.18143457  0.9949577 ]
# Well name 8-13 and its coordinate: [ 7.875311   -0.16521509  0.9945375 ]
# Well name 8-14 and its coordinate: [12.504916   -0.14899561  0.99411726]
# Well name 8-15 and its coordinate: [17.134521   -0.13277613  0.9936971 ]
# Well name 8-16 and its coordinate: [21.764128   -0.11655665  0.9932769 ]
# Well name 8-17 and its coordinate: [26.393734   -0.10033718  0.9928567 ]
# Well name 8-18 and its coordinate: [31.023338  -0.0841177  0.9924365]
# Well name 8-19 and its coordinate: [35.652946   -0.06789822  0.9920163 ]
# Well name 8-20 and its coordinate: [40.28255    -0.05167874  0.9915961 ]
# Well name 8-21 and its coordinate: [ 4.4912155e+01 -3.5459261e-02  9.9117595e-01]
# Well name 8-22 and its coordinate: [ 4.9541763e+01 -1.9239783e-02  9.9075574e-01]
# Well name 8-23 and its coordinate: [ 5.4171368e+01 -3.0203050e-03  9.9033552e-01]
# Well name 8-24 and its coordinate: [5.8800972e+01 1.3199174e-02 9.8991537e-01]
# Well name 9-1 and its coordinate: [-47.67996    -5.1378403   0.9995798]
# Well name 9-2 and its coordinate: [-43.05035     -5.1216207    0.99915963]
# Well name 9-3 and its coordinate: [-38.420746   -5.105401    0.9987394]
# Well name 9-4 and its coordinate: [-33.79114    -5.089182    0.9983192]
# Well name 9-5 and its coordinate: [-29.161535    -5.0729623    0.99789906]
# Well name 9-6 and its coordinate: [-24.531929    -5.0567427    0.99747884]
# Well name 9-7 and its coordinate: [-19.902323    -5.040523     0.99705863]
# Well name 9-8 and its coordinate: [-15.272717   -5.024304    0.9966385]
# Well name 9-9 and its coordinate: [-10.643112    -5.0080843    0.99621826]
# Well name 9-10 and its coordinate: [-6.0135064  -4.9918647   0.99579805]
# Well name 9-11 and its coordinate: [-1.3839006 -4.9756455  0.9953779]
# Well name 9-12 and its coordinate: [ 3.2457051 -4.959426   0.9949577]
# Well name 9-13 and its coordinate: [ 7.875311  -4.9432063  0.9945375]
# Well name 9-14 and its coordinate: [12.504916   -4.9269867   0.99411726]
# Well name 9-15 and its coordinate: [17.134521  -4.9107676  0.9936971]
# Well name 9-16 and its coordinate: [21.764128  -4.894548   0.9932769]
# Well name 9-17 and its coordinate: [26.393734  -4.8783283  0.9928567]
# Well name 9-18 and its coordinate: [31.023338  -4.862109   0.9924365]
# Well name 9-19 and its coordinate: [35.652946  -4.8458896  0.9920163]
# Well name 9-20 and its coordinate: [40.28255   -4.82967    0.9915961]
# Well name 9-21 and its coordinate: [44.912155   -4.8134503   0.99117595]
# Well name 9-22 and its coordinate: [49.541763   -4.797231    0.99075574]
# Well name 9-23 and its coordinate: [54.171368  -4.7810116  0.9903355]
# Well name 9-24 and its coordinate: [58.800972  -4.764792   0.9899154]
# Well name 10-1 and its coordinate: [-47.67996    -9.915832    0.9995798]
# Well name 10-2 and its coordinate: [-43.05035     -9.899611     0.99915963]
# Well name 10-3 and its coordinate: [-38.420746   -9.883392    0.9987394]
# Well name 10-4 and its coordinate: [-33.79114    -9.867173    0.9983192]
# Well name 10-5 and its coordinate: [-29.161535    -9.850953     0.99789906]
# Well name 10-6 and its coordinate: [-24.531929    -9.834734     0.99747884]
# Well name 10-7 and its coordinate: [-19.902323    -9.818515     0.99705863]
# Well name 10-8 and its coordinate: [-15.272717   -9.802295    0.9966385]
# Well name 10-9 and its coordinate: [-10.643112    -9.786076     0.99621826]
# Well name 10-10 and its coordinate: [-6.0135064  -9.769856    0.99579805]
# Well name 10-11 and its coordinate: [-1.3839006 -9.753636   0.9953779]
# Well name 10-12 and its coordinate: [ 3.2457051 -9.737417   0.9949577]
# Well name 10-13 and its coordinate: [ 7.875311  -9.721198   0.9945375]
# Well name 10-14 and its coordinate: [12.504916   -9.704978    0.99411726]
# Well name 10-15 and its coordinate: [17.134521  -9.688759   0.9936971]
# Well name 10-16 and its coordinate: [21.764128  -9.672539   0.9932769]
# Well name 10-17 and its coordinate: [26.393734  -9.65632    0.9928567]
# Well name 10-18 and its coordinate: [31.023338  -9.6401005  0.9924365]
# Well name 10-19 and its coordinate: [35.652946  -9.62388    0.9920163]
# Well name 10-20 and its coordinate: [40.28255   -9.607661   0.9915961]
# Well name 10-21 and its coordinate: [44.912155   -9.591442    0.99117595]
# Well name 10-22 and its coordinate: [49.541763   -9.575222    0.99075574]
# Well name 10-23 and its coordinate: [54.171368  -9.559003   0.9903355]
# Well name 10-24 and its coordinate: [58.800972  -9.542784   0.9899154]
# Well name 11-1 and its coordinate: [-47.67996   -14.693823    0.9995798]
# Well name 11-2 and its coordinate: [-43.05035    -14.677603     0.99915963]
# Well name 11-3 and its coordinate: [-38.420746  -14.661384    0.9987394]
# Well name 11-4 and its coordinate: [-33.79114   -14.6451645   0.9983192]
# Well name 11-5 and its coordinate: [-29.161535   -14.628944     0.99789906]
# Well name 11-6 and its coordinate: [-24.531929   -14.612725     0.99747884]
# Well name 11-7 and its coordinate: [-19.902323   -14.596506     0.99705863]
# Well name 11-8 and its coordinate: [-15.272717  -14.580286    0.9966385]
# Well name 11-9 and its coordinate: [-10.643112   -14.564067     0.99621826]
# Well name 11-10 and its coordinate: [ -6.0135064  -14.547848     0.99579805]
# Well name 11-11 and its coordinate: [ -1.3839006 -14.531628    0.9953779]
# Well name 11-12 and its coordinate: [  3.2457051 -14.5154085   0.9949577]
# Well name 11-13 and its coordinate: [  7.875311  -14.499189    0.9945375]
# Well name 11-14 and its coordinate: [ 12.504916   -14.482969     0.99411726]
# Well name 11-15 and its coordinate: [ 17.134521  -14.46675     0.9936971]
# Well name 11-16 and its coordinate: [ 21.764128  -14.45053     0.9932769]
# Well name 11-17 and its coordinate: [ 26.393734  -14.434311    0.9928567]
# Well name 11-18 and its coordinate: [ 31.023338  -14.418092    0.9924365]
# Well name 11-19 and its coordinate: [ 35.652946  -14.401872    0.9920163]
# Well name 11-20 and its coordinate: [ 40.28255   -14.385653    0.9915961]
# Well name 11-21 and its coordinate: [ 44.912155   -14.369433     0.99117595]
# Well name 11-22 and its coordinate: [ 49.541763   -14.353213     0.99075574]
# Well name 11-23 and its coordinate: [ 54.171368  -14.336994    0.9903355]
# Well name 13-18 and its coordinate: [ 31.023338  -23.974073    0.9924365]
# Well name 13-19 and its coordinate: [ 35.652946  -23.957855    0.9920163]
# Well name 13-20 and its coordinate: [ 40.28255   -23.941635    0.9915961]
# Well name 13-21 and its coordinate: [ 44.912155   -23.925415     0.99117595]
# Well name 13-22 and its coordinate: [ 49.541763   -23.909197     0.99075574]
# Well name 13-23 and its coordinate: [ 54.171368  -23.892977    0.9903355]
# Well name 13-24 and its coordinate: [ 58.800972  -23.876757    0.9899154]
# Well name 14-1 and its coordinate: [-47.67996   -29.027796    0.9995798]
# Well name 14-2 and its coordinate: [-43.05035    -29.011578     0.99915963]
# Well name 14-3 and its coordinate: [-38.420746  -28.995358    0.9987394]
# Well name 14-4 and its coordinate: [-33.79114   -28.979137    0.9983192]
# Well name 14-5 and its coordinate: [-29.161535   -28.96292      0.99789906]
# Well name 14-6 and its coordinate: [-24.531929   -28.9467       0.99747884]
# Well name 14-7 and its coordinate: [-19.902323   -28.93048      0.99705863]
# Well name 14-8 and its coordinate: [-15.272717  -28.91426     0.9966385]
# Well name 14-9 and its coordinate: [-10.643112   -28.89804      0.99621826]
# Well name 14-10 and its coordinate: [ -6.0135064  -28.88182      0.99579805]
# Well name 14-11 and its coordinate: [ -1.3839006 -28.865602    0.9953779]
# Well name 14-12 and its coordinate: [  3.2457051 -28.849382    0.9949577]
# Well name 14-13 and its coordinate: [  7.875311  -28.833162    0.9945375]
# Well name 14-14 and its coordinate: [ 12.504916   -28.816944     0.99411726]
# Well name 14-15 and its coordinate: [ 17.134521  -28.800724    0.9936971]
# Well name 14-16 and its coordinate: [ 21.764128  -28.784504    0.9932769]
# Well name 14-17 and its coordinate: [ 26.393734  -28.768286    0.9928567]
# Well name 14-18 and its coordinate: [ 31.023338  -28.752066    0.9924365]
# Well name 14-19 and its coordinate: [ 35.652946  -28.735846    0.9920163]
# Well name 14-20 and its coordinate: [ 40.28255   -28.719625    0.9915961]
# Well name 14-21 and its coordinate: [ 44.912155   -28.703407     0.99117595]
# Well name 14-22 and its coordinate: [ 49.541763   -28.687187     0.99075574]
# Well name 14-23 and its coordinate: [ 54.171368  -28.670967    0.9903355]
# Well name 14-24 and its coordinate: [ 58.800972  -28.654749    0.9899154]
# Well name 15-1 and its coordinate: [-47.67996   -33.805786    0.9995798]
# Well name 15-2 and its coordinate: [-43.05035    -33.78957      0.99915963]
# Well name 15-3 and its coordinate: [-38.420746  -33.77335     0.9987394]
# Well name 15-4 and its coordinate: [-33.79114   -33.75713     0.9983192]
# Well name 15-5 and its coordinate: [-29.161535   -33.74091      0.99789906]
# Well name 15-6 and its coordinate: [-24.531929   -33.72469      0.99747884]
# Well name 15-7 and its coordinate: [-19.902323   -33.70847      0.99705863]
# Well name 15-8 and its coordinate: [-15.272717  -33.692253    0.9966385]
# Well name 15-9 and its coordinate: [-10.643112   -33.676033     0.99621826]
# Well name 15-10 and its coordinate: [ -6.0135064  -33.659813     0.99579805]
# Well name 15-11 and its coordinate: [ -1.3839006 -33.643593    0.9953779]
# Well name 15-12 and its coordinate: [  3.2457051 -33.627373    0.9949577]
# Well name 15-13 and its coordinate: [  7.875311  -33.611153    0.9945375]
# Well name 15-14 and its coordinate: [ 12.504916   -33.594936     0.99411726]
# Well name 15-15 and its coordinate: [ 17.134521  -33.578716    0.9936971]
# Well name 15-16 and its coordinate: [ 21.764128  -33.562496    0.9932769]
# Well name 15-17 and its coordinate: [ 26.393734  -33.546276    0.9928567]
# Well name 15-18 and its coordinate: [ 31.023338  -33.530056    0.9924365]
# Well name 15-19 and its coordinate: [ 35.652946  -33.513836    0.9920163]
# Well name 15-20 and its coordinate: [ 40.28255   -33.497616    0.9915961]
# Well name 15-21 and its coordinate: [ 44.912155   -33.4814       0.99117595]
# Well name 15-22 and its coordinate: [ 49.541763   -33.46518      0.99075574]
# Well name 15-23 and its coordinate: [ 54.171368  -33.44896     0.9903355]
# Well name 15-24 and its coordinate: [ 58.800972  -33.43274     0.9899154]
# Well name 16-1 and its coordinate: [-47.67996   -38.58378     0.9995798]
# Well name 16-2 and its coordinate: [-43.05035    -38.56756      0.99915963]
# Well name 16-3 and its coordinate: [-38.420746  -38.55134     0.9987394]
# Well name 16-4 and its coordinate: [-33.79114   -38.535122    0.9983192]
# Well name 16-5 and its coordinate: [-29.161535   -38.5189       0.99789906]
# Well name 16-6 and its coordinate: [-24.531929   -38.50268      0.99747884]
# Well name 16-7 and its coordinate: [-19.902323   -38.48646      0.99705863]
# Well name 16-8 and its coordinate: [-15.272717  -38.47024     0.9966385]
# Well name 16-9 and its coordinate: [-10.643112   -38.45402      0.99621826]
# Well name 16-10 and its coordinate: [ -6.0135064  -38.437805     0.99579805]
# Well name 16-11 and its coordinate: [ -1.3839006 -38.421585    0.9953779]
# Well name 16-12 and its coordinate: [  3.2457051 -38.405365    0.9949577]
# Well name 16-13 and its coordinate: [  7.875311  -38.389145    0.9945375]
# Well name 16-14 and its coordinate: [ 12.504916   -38.372925     0.99411726]
# Well name 16-15 and its coordinate: [ 17.134521  -38.356705    0.9936971]
# Well name 16-16 and its coordinate: [ 21.764128  -38.34049     0.9932769]
# Well name 16-17 and its coordinate: [ 26.393734  -38.32427     0.9928567]
# Well name 16-18 and its coordinate: [ 31.023338  -38.30805     0.9924365]
# Well name 16-19 and its coordinate: [ 35.652946  -38.29183     0.9920163]
# Well name 16-20 and its coordinate: [ 40.28255   -38.275608    0.9915961]
# Well name 16-21 and its coordinate: [ 44.912155   -38.259388     0.99117595]
# Well name 16-22 and its coordinate: [ 49.541763   -38.24317      0.99075574]
# Well name 16-23 and its coordinate: [ 54.171368  -38.22695     0.9903355]
# Well name 16-24 and its coordinate: [ 58.800972  -38.21073     0.9899154]

# %% [markdown]
# ### Try 5: Eigendecomposition Homography

# %%
vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Homography", algorithm_H="Eigendecomposition", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot()

vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
    

for vector in vectors:
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    
plt.show()
# Out:
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Homography
# Learning the homography matrix using Eigendecomposition to map from well plate row and column arrangement to xzy-stage coordinate space
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -40.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0

# %% [markdown]
# # Perspective transformation with 5mm displacement in x and y axis of well plate in xyz coordinates

# %%
import json
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from DragonFlyWellPlateAutomation.devices.wellplate import WellPlate as wp


WellPlate = wp()
WellPlate.well_plate_req_coords["Top right well"] = WellPlate.vector_2_state_dict(tr)
WellPlate.well_plate_req_coords["Top left well"] = WellPlate.vector_2_state_dict(tl)
WellPlate.well_plate_req_coords["Bottom left well"] = WellPlate.vector_2_state_dict(bl)

vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Homography", algorithm_H="Levenberg-Marquardt", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot(xmin=-50-5, 
    xmax=60-5,
    ymin=-38-5,
    ymax= 34-5)

vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
for vector, wellname in zip(vectors,well_names):
    print("Well name {} and its coordinate: {}".format(wellname, vector))
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    axis.text(x, y, wellname, ha='center', va='bottom',fontsize="xx-small")

plt.tight_layout()
plt.show()
# Out:
# search for root_dir and set working directory
# Working directory set to: /media/ibrahim/Extended Storage/cloud/Internship/bioquant/348_wellplate_automation
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Homography
# Learning the homography matrix using Levenberg-Marquardt to map from well plate row and column arrangement to xzy-stage coordinate space
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -45.0 and Ymax 29.0
# Xmin -55.0 and Xmax 55.0
# Well name 1-1 and its coordinate: [-47.67996    33.08609     0.9995798]
# Well name 1-2 and its coordinate: [-43.05035     33.10231      0.99915963]
# Well name 1-3 and its coordinate: [-38.420746   33.11853     0.9987394]
# Well name 1-4 and its coordinate: [-33.79114    33.13475     0.9983192]
# Well name 1-5 and its coordinate: [-29.161535    33.150967     0.99789906]
# Well name 1-6 and its coordinate: [-24.531929    33.167187     0.99747884]
# Well name 1-7 and its coordinate: [-19.902323    33.183407     0.99705863]
# Well name 1-8 and its coordinate: [-15.272717   33.199627    0.9966385]
# Well name 1-9 and its coordinate: [-10.643112    33.215847     0.99621826]
# Well name 1-10 and its coordinate: [-6.0135064  33.232067    0.99579805]
# Well name 1-11 and its coordinate: [-1.3839006 33.248283   0.9953779]
# Well name 1-12 and its coordinate: [ 3.2457051 33.264503   0.9949577]
# Well name 1-13 and its coordinate: [ 7.875311  33.280724   0.9945375]
# Well name 1-14 and its coordinate: [12.504916   33.296944    0.99411726]
# Well name 1-15 and its coordinate: [17.134521  33.313164   0.9936971]
# Well name 1-16 and its coordinate: [21.764128  33.329384   0.9932769]
# Well name 1-17 and its coordinate: [26.393734  33.3456     0.9928567]
# Well name 1-18 and its coordinate: [31.023338  33.36182    0.9924365]
# Well name 1-19 and its coordinate: [35.652946  33.37804    0.9920163]
# Well name 1-20 and its coordinate: [40.28255   33.39426    0.9915961]
# Well name 1-21 and its coordinate: [44.912155   33.41048     0.99117595]
# Well name 1-22 and its coordinate: [49.541763   33.4267      0.99075574]
# Well name 1-23 and its coordinate: [54.171368  33.442917   0.9903355]
# Well name 1-24 and its coordinate: [58.800972  33.459137   0.9899154]
# Well name 2-1 and its coordinate: [-47.67996    28.308098    0.9995798]
# Well name 2-2 and its coordinate: [-43.05035     28.324318     0.99915963]
# Well name 2-3 and its coordinate: [-38.420746   28.340538    0.9987394]
# Well name 2-4 and its coordinate: [-33.79114    28.356758    0.9983192]
# Well name 2-5 and its coordinate: [-29.161535    28.372976     0.99789906]
# Well name 2-6 and its coordinate: [-24.531929    28.389196     0.99747884]
# Well name 2-7 and its coordinate: [-19.902323    28.405416     0.99705863]
# Well name 2-8 and its coordinate: [-15.272717   28.421635    0.9966385]
# Well name 2-9 and its coordinate: [-10.643112    28.437855     0.99621826]
# Well name 2-10 and its coordinate: [-6.0135064  28.454075    0.99579805]
# Well name 2-11 and its coordinate: [-1.3839006 28.470293   0.9953779]
# Well name 2-12 and its coordinate: [ 3.2457051 28.486513   0.9949577]
# Well name 2-13 and its coordinate: [ 7.875311  28.502733   0.9945375]
# Well name 2-14 and its coordinate: [12.504916   28.518951    0.99411726]
# Well name 2-15 and its coordinate: [17.134521  28.535172   0.9936971]
# Well name 2-16 and its coordinate: [21.764128  28.551392   0.9932769]
# Well name 2-17 and its coordinate: [26.393734  28.56761    0.9928567]
# Well name 2-18 and its coordinate: [31.023338  28.58383    0.9924365]
# Well name 2-19 and its coordinate: [35.652946  28.60005    0.9920163]
# Well name 2-20 and its coordinate: [40.28255   28.616268   0.9915961]
# Well name 2-21 and its coordinate: [44.912155   28.632488    0.99117595]
# Well name 2-22 and its coordinate: [49.541763   28.648708    0.99075574]
# Well name 2-23 and its coordinate: [54.171368  28.664927   0.9903355]
# Well name 2-24 and its coordinate: [58.800972  28.681147   0.9899154]
# Well name 3-1 and its coordinate: [-47.67996    23.530107    0.9995798]
# Well name 3-2 and its coordinate: [-43.05035     23.546328     0.99915963]
# Well name 3-3 and its coordinate: [-38.420746   23.562546    0.9987394]
# Well name 3-4 and its coordinate: [-33.79114    23.578766    0.9983192]
# Well name 3-5 and its coordinate: [-29.161535    23.594986     0.99789906]
# Well name 3-6 and its coordinate: [-24.531929    23.611204     0.99747884]
# Well name 3-7 and its coordinate: [-19.902323    23.627424     0.99705863]
# Well name 3-8 and its coordinate: [-15.272717   23.643644    0.9966385]
# Well name 3-9 and its coordinate: [-10.643112    23.659863     0.99621826]
# Well name 3-10 and its coordinate: [-6.0135064  23.676083    0.99579805]
# Well name 3-11 and its coordinate: [-1.3839006 23.692303   0.9953779]
# Well name 3-12 and its coordinate: [ 3.2457051 23.70852    0.9949577]
# Well name 3-13 and its coordinate: [ 7.875311  23.724741   0.9945375]
# Well name 3-14 and its coordinate: [12.504916   23.740961    0.99411726]
# Well name 3-15 and its coordinate: [17.134521  23.757181   0.9936971]
# Well name 3-16 and its coordinate: [21.764128  23.7734     0.9932769]
# Well name 3-17 and its coordinate: [26.393734  23.78962    0.9928567]
# Well name 3-18 and its coordinate: [31.023338  23.80584    0.9924365]
# Well name 3-19 and its coordinate: [35.652946  23.822058   0.9920163]
# Well name 3-20 and its coordinate: [40.28255   23.838278   0.9915961]
# Well name 3-21 and its coordinate: [44.912155   23.854498    0.99117595]
# Well name 3-22 and its coordinate: [49.541763   23.870716    0.99075574]
# Well name 3-23 and its coordinate: [54.171368  23.886936   0.9903355]
# Well name 3-24 and its coordinate: [58.800972  23.903156   0.9899154]
# Well name 4-1 and its coordinate: [-47.67996    18.752117    0.9995798]
# Well name 4-2 and its coordinate: [-43.05035     18.768335     0.99915963]
# Well name 4-3 and its coordinate: [-38.420746   18.784555    0.9987394]
# Well name 4-4 and its coordinate: [-33.79114    18.800776    0.9983192]
# Well name 4-5 and its coordinate: [-29.161535    18.816994     0.99789906]
# Well name 4-6 and its coordinate: [-24.531929    18.833214     0.99747884]
# Well name 4-7 and its coordinate: [-19.902323    18.849434     0.99705863]
# Well name 4-8 and its coordinate: [-15.272717   18.865652    0.9966385]
# Well name 4-9 and its coordinate: [-10.643112    18.881872     0.99621826]
# Well name 4-10 and its coordinate: [-6.0135064  18.898092    0.99579805]
# Well name 4-11 and its coordinate: [-1.3839006 18.91431    0.9953779]
# Well name 4-12 and its coordinate: [ 3.2457051 18.93053    0.9949577]
# Well name 4-13 and its coordinate: [ 7.875311  18.94675    0.9945375]
# Well name 4-14 and its coordinate: [12.504916   18.962969    0.99411726]
# Well name 4-15 and its coordinate: [17.134521  18.979189   0.9936971]
# Well name 4-16 and its coordinate: [21.764128  18.995409   0.9932769]
# Well name 4-17 and its coordinate: [26.393734  19.011627   0.9928567]
# Well name 4-18 and its coordinate: [31.023338  19.027847   0.9924365]
# Well name 4-19 and its coordinate: [35.652946  19.044067   0.9920163]
# Well name 4-20 and its coordinate: [40.28255   19.060286   0.9915961]
# Well name 4-21 and its coordinate: [44.912155   19.076506    0.99117595]
# Well name 4-22 and its coordinate: [49.541763   19.092726    0.99075574]
# Well name 4-23 and its coordinate: [54.171368  19.108944   0.9903355]
# Well name 4-24 and its coordinate: [58.800972  19.125164   0.9899154]
# Well name 5-1 and its coordinate: [-47.67996    13.974125    0.9995798]
# Well name 5-2 and its coordinate: [-43.05035     13.990344     0.99915963]
# Well name 5-3 and its coordinate: [-38.420746   14.006564    0.9987394]
# Well name 5-4 and its coordinate: [-33.79114    14.022783    0.9983192]
# Well name 5-5 and its coordinate: [-29.161535    14.039002     0.99789906]
# Well name 5-6 and its coordinate: [-24.531929    14.0552225    0.99747884]
# Well name 5-7 and its coordinate: [-19.902323    14.071442     0.99705863]
# Well name 5-8 and its coordinate: [-15.272717   14.087662    0.9966385]
# Well name 5-9 and its coordinate: [-10.643112    14.103881     0.99621826]
# Well name 5-10 and its coordinate: [-6.0135064  14.1201      0.99579805]
# Well name 5-11 and its coordinate: [-1.3839006 14.13632    0.9953779]
# Well name 5-12 and its coordinate: [ 3.2457051 14.152539   0.9949577]
# Well name 5-13 and its coordinate: [ 7.875311  14.168758   0.9945375]
# Well name 5-14 and its coordinate: [12.504916   14.1849785   0.99411726]
# Well name 5-15 and its coordinate: [17.134521  14.201198   0.9936971]
# Well name 5-16 and its coordinate: [21.764128  14.217417   0.9932769]
# Well name 5-17 and its coordinate: [26.393734  14.233637   0.9928567]
# Well name 5-18 and its coordinate: [31.023338  14.249856   0.9924365]
# Well name 5-19 and its coordinate: [35.652946  14.266075   0.9920163]
# Well name 5-20 and its coordinate: [40.28255   14.282295   0.9915961]
# Well name 5-21 and its coordinate: [44.912155   14.298514    0.99117595]
# Well name 5-22 and its coordinate: [49.541763   14.314734    0.99075574]
# Well name 5-23 and its coordinate: [54.171368  14.330954   0.9903355]
# Well name 5-24 and its coordinate: [58.800972  14.347173   0.9899154]
# Well name 6-1 and its coordinate: [-47.67996     9.196134    0.9995798]
# Well name 6-2 and its coordinate: [-43.05035      9.212353     0.99915963]
# Well name 6-3 and its coordinate: [-38.420746    9.228573    0.9987394]
# Well name 6-4 and its coordinate: [-33.79114     9.244792    0.9983192]
# Well name 6-5 and its coordinate: [-29.161535     9.261012     0.99789906]
# Well name 6-6 and its coordinate: [-24.531929     9.277231     0.99747884]
# Well name 6-7 and its coordinate: [-19.902323     9.29345      0.99705863]
# Well name 6-8 and its coordinate: [-15.272717    9.30967     0.9966385]
# Well name 6-9 and its coordinate: [-10.643112     9.32589      0.99621826]
# Well name 6-10 and its coordinate: [-6.0135064   9.342109    0.99579805]
# Well name 6-11 and its coordinate: [-1.3839006  9.358329   0.9953779]
# Well name 6-12 and its coordinate: [3.2457051 9.374548  0.9949577]
# Well name 6-13 and its coordinate: [7.875311  9.390767  0.9945375]
# Well name 6-14 and its coordinate: [12.504916    9.406987    0.99411726]
# Well name 6-15 and its coordinate: [17.134521   9.423206   0.9936971]
# Well name 6-16 and its coordinate: [21.764128   9.439425   0.9932769]
# Well name 6-17 and its coordinate: [26.393734   9.455646   0.9928567]
# Well name 6-18 and its coordinate: [31.023338   9.471865   0.9924365]
# Well name 6-19 and its coordinate: [35.652946   9.488085   0.9920163]
# Well name 6-20 and its coordinate: [40.28255    9.504304   0.9915961]
# Well name 6-21 and its coordinate: [44.912155    9.520523    0.99117595]
# Well name 6-22 and its coordinate: [49.541763    9.536743    0.99075574]
# Well name 6-23 and its coordinate: [54.171368   9.552962   0.9903355]
# Well name 6-24 and its coordinate: [58.800972   9.569181   0.9899154]
# Well name 7-1 and its coordinate: [-47.67996     4.4181423   0.9995798]
# Well name 7-2 and its coordinate: [-43.05035      4.434362     0.99915963]
# Well name 7-3 and its coordinate: [-38.420746    4.4505816   0.9987394]
# Well name 7-4 and its coordinate: [-33.79114     4.4668007   0.9983192]
# Well name 7-5 and its coordinate: [-29.161535     4.4830203    0.99789906]
# Well name 7-6 and its coordinate: [-24.531929     4.49924      0.99747884]
# Well name 7-7 and its coordinate: [-19.902323     4.5154595    0.99705863]
# Well name 7-8 and its coordinate: [-15.272717    4.5316787   0.9966385]
# Well name 7-9 and its coordinate: [-10.643112     4.5478983    0.99621826]
# Well name 7-10 and its coordinate: [-6.0135064   4.564118    0.99579805]
# Well name 7-11 and its coordinate: [-1.3839006  4.580337   0.9953779]
# Well name 7-12 and its coordinate: [3.2457051 4.5965567 0.9949577]
# Well name 7-13 and its coordinate: [7.875311  4.6127763 0.9945375]
# Well name 7-14 and its coordinate: [12.504916    4.628996    0.99411726]
# Well name 7-15 and its coordinate: [17.134521   4.645215   0.9936971]
# Well name 7-16 and its coordinate: [21.764128   4.6614347  0.9932769]
# Well name 7-17 and its coordinate: [26.393734   4.6776543  0.9928567]
# Well name 7-18 and its coordinate: [31.023338   4.6938734  0.9924365]
# Well name 7-19 and its coordinate: [35.652946   4.710093   0.9920163]
# Well name 7-20 and its coordinate: [40.28255    4.7263126  0.9915961]
# Well name 7-21 and its coordinate: [44.912155    4.742532    0.99117595]
# Well name 7-22 and its coordinate: [49.541763    4.7587514   0.99075574]
# Well name 7-23 and its coordinate: [54.171368   4.774971   0.9903355]
# Well name 7-24 and its coordinate: [58.800972   4.7911906  0.9899154]
# Well name 8-1 and its coordinate: [-47.67996     -0.35984883   0.9995798 ]
# Well name 8-2 and its coordinate: [-43.05035     -0.34362936   0.99915963]
# Well name 8-3 and its coordinate: [-38.420746    -0.32740986   0.9987394 ]
# Well name 8-4 and its coordinate: [-33.79114    -0.3111904   0.9983192]
# Well name 8-5 and its coordinate: [-29.161535    -0.29497093   0.99789906]
# Well name 8-6 and its coordinate: [-24.531929    -0.27875143   0.99747884]
# Well name 8-7 and its coordinate: [-19.902323    -0.26253197   0.99705863]
# Well name 8-8 and its coordinate: [-15.272717    -0.24631248   0.9966385 ]
# Well name 8-9 and its coordinate: [-10.643112    -0.230093     0.99621826]
# Well name 8-10 and its coordinate: [-6.0135064  -0.21387352  0.99579805]
# Well name 8-11 and its coordinate: [-1.3839006  -0.19765405  0.9953779 ]
# Well name 8-12 and its coordinate: [ 3.2457051  -0.18143457  0.9949577 ]
# Well name 8-13 and its coordinate: [ 7.875311   -0.16521509  0.9945375 ]
# Well name 8-14 and its coordinate: [12.504916   -0.14899561  0.99411726]
# Well name 8-15 and its coordinate: [17.134521   -0.13277613  0.9936971 ]
# Well name 8-16 and its coordinate: [21.764128   -0.11655665  0.9932769 ]
# Well name 8-17 and its coordinate: [26.393734   -0.10033718  0.9928567 ]
# Well name 8-18 and its coordinate: [31.023338  -0.0841177  0.9924365]
# Well name 8-19 and its coordinate: [35.652946   -0.06789822  0.9920163 ]
# Well name 8-20 and its coordinate: [40.28255    -0.05167874  0.9915961 ]
# Well name 8-21 and its coordinate: [ 4.4912155e+01 -3.5459261e-02  9.9117595e-01]
# Well name 8-22 and its coordinate: [ 4.9541763e+01 -1.9239783e-02  9.9075574e-01]
# Well name 8-23 and its coordinate: [ 5.4171368e+01 -3.0203050e-03  9.9033552e-01]
# Well name 8-24 and its coordinate: [5.8800972e+01 1.3199174e-02 9.8991537e-01]
# Well name 9-1 and its coordinate: [-47.67996    -5.1378403   0.9995798]
# Well name 9-2 and its coordinate: [-43.05035     -5.1216207    0.99915963]
# Well name 9-3 and its coordinate: [-38.420746   -5.105401    0.9987394]
# Well name 9-4 and its coordinate: [-33.79114    -5.089182    0.9983192]
# Well name 9-5 and its coordinate: [-29.161535    -5.0729623    0.99789906]
# Well name 9-6 and its coordinate: [-24.531929    -5.0567427    0.99747884]
# Well name 9-7 and its coordinate: [-19.902323    -5.040523     0.99705863]
# Well name 9-8 and its coordinate: [-15.272717   -5.024304    0.9966385]
# Well name 9-9 and its coordinate: [-10.643112    -5.0080843    0.99621826]
# Well name 9-10 and its coordinate: [-6.0135064  -4.9918647   0.99579805]
# Well name 9-11 and its coordinate: [-1.3839006 -4.9756455  0.9953779]
# Well name 9-12 and its coordinate: [ 3.2457051 -4.959426   0.9949577]
# Well name 9-13 and its coordinate: [ 7.875311  -4.9432063  0.9945375]
# Well name 9-14 and its coordinate: [12.504916   -4.9269867   0.99411726]
# Well name 9-15 and its coordinate: [17.134521  -4.9107676  0.9936971]
# Well name 9-16 and its coordinate: [21.764128  -4.894548   0.9932769]
# Well name 9-17 and its coordinate: [26.393734  -4.8783283  0.9928567]
# Well name 9-18 and its coordinate: [31.023338  -4.862109   0.9924365]
# Well name 9-19 and its coordinate: [35.652946  -4.8458896  0.9920163]
# Well name 9-20 and its coordinate: [40.28255   -4.82967    0.9915961]
# Well name 9-21 and its coordinate: [44.912155   -4.8134503   0.99117595]
# Well name 9-22 and its coordinate: [49.541763   -4.797231    0.99075574]
# Well name 9-23 and its coordinate: [54.171368  -4.7810116  0.9903355]
# Well name 9-24 and its coordinate: [58.800972  -4.764792   0.9899154]
# Well name 10-1 and its coordinate: [-47.67996    -9.915832    0.9995798]
# Well name 10-2 and its coordinate: [-43.05035     -9.899611     0.99915963]
# Well name 10-3 and its coordinate: [-38.420746   -9.883392    0.9987394]
# Well name 10-4 and its coordinate: [-33.79114    -9.867173    0.9983192]
# Well name 10-5 and its coordinate: [-29.161535    -9.850953     0.99789906]
# Well name 10-6 and its coordinate: [-24.531929    -9.834734     0.99747884]
# Well name 10-7 and its coordinate: [-19.902323    -9.818515     0.99705863]
# Well name 10-8 and its coordinate: [-15.272717   -9.802295    0.9966385]
# Well name 10-9 and its coordinate: [-10.643112    -9.786076     0.99621826]
# Well name 10-10 and its coordinate: [-6.0135064  -9.769856    0.99579805]
# Well name 10-11 and its coordinate: [-1.3839006 -9.753636   0.9953779]
# Well name 10-12 and its coordinate: [ 3.2457051 -9.737417   0.9949577]
# Well name 10-13 and its coordinate: [ 7.875311  -9.721198   0.9945375]
# Well name 10-14 and its coordinate: [12.504916   -9.704978    0.99411726]
# Well name 10-15 and its coordinate: [17.134521  -9.688759   0.9936971]
# Well name 10-16 and its coordinate: [21.764128  -9.672539   0.9932769]
# Well name 10-17 and its coordinate: [26.393734  -9.65632    0.9928567]
# Well name 10-18 and its coordinate: [31.023338  -9.6401005  0.9924365]
# Well name 10-19 and its coordinate: [35.652946  -9.62388    0.9920163]
# Well name 10-20 and its coordinate: [40.28255   -9.607661   0.9915961]
# Well name 10-21 and its coordinate: [44.912155   -9.591442    0.99117595]
# Well name 10-22 and its coordinate: [49.541763   -9.575222    0.99075574]
# Well name 10-23 and its coordinate: [54.171368  -9.559003   0.9903355]
# Well name 10-24 and its coordinate: [58.800972  -9.542784   0.9899154]
# Well name 11-1 and its coordinate: [-47.67996   -14.693823    0.9995798]
# Well name 11-2 and its coordinate: [-43.05035    -14.677603     0.99915963]
# Well name 11-3 and its coordinate: [-38.420746  -14.661384    0.9987394]
# Well name 11-4 and its coordinate: [-33.79114   -14.6451645   0.9983192]
# Well name 14-17 and its coordinate: [ 26.393734  -28.768286    0.9928567]
# Well name 14-18 and its coordinate: [ 31.023338  -28.752066    0.9924365]
# Well name 14-19 and its coordinate: [ 35.652946  -28.735846    0.9920163]
# Well name 14-20 and its coordinate: [ 40.28255   -28.719625    0.9915961]
# Well name 14-21 and its coordinate: [ 44.912155   -28.703407     0.99117595]
# Well name 14-22 and its coordinate: [ 49.541763   -28.687187     0.99075574]
# Well name 14-23 and its coordinate: [ 54.171368  -28.670967    0.9903355]
# Well name 14-24 and its coordinate: [ 58.800972  -28.654749    0.9899154]
# Well name 15-1 and its coordinate: [-47.67996   -33.805786    0.9995798]
# Well name 15-2 and its coordinate: [-43.05035    -33.78957      0.99915963]
# Well name 15-3 and its coordinate: [-38.420746  -33.77335     0.9987394]
# Well name 15-4 and its coordinate: [-33.79114   -33.75713     0.9983192]
# Well name 15-5 and its coordinate: [-29.161535   -33.74091      0.99789906]
# Well name 15-6 and its coordinate: [-24.531929   -33.72469      0.99747884]
# Well name 15-7 and its coordinate: [-19.902323   -33.70847      0.99705863]
# Well name 15-8 and its coordinate: [-15.272717  -33.692253    0.9966385]
# Well name 15-9 and its coordinate: [-10.643112   -33.676033     0.99621826]
# Well name 15-10 and its coordinate: [ -6.0135064  -33.659813     0.99579805]
# Well name 15-11 and its coordinate: [ -1.3839006 -33.643593    0.9953779]
# Well name 15-12 and its coordinate: [  3.2457051 -33.627373    0.9949577]
# Well name 15-13 and its coordinate: [  7.875311  -33.611153    0.9945375]
# Well name 15-14 and its coordinate: [ 12.504916   -33.594936     0.99411726]
# Well name 15-15 and its coordinate: [ 17.134521  -33.578716    0.9936971]
# Well name 15-16 and its coordinate: [ 21.764128  -33.562496    0.9932769]
# Well name 15-17 and its coordinate: [ 26.393734  -33.546276    0.9928567]
# Well name 15-18 and its coordinate: [ 31.023338  -33.530056    0.9924365]
# Well name 15-19 and its coordinate: [ 35.652946  -33.513836    0.9920163]
# Well name 15-20 and its coordinate: [ 40.28255   -33.497616    0.9915961]
# Well name 15-21 and its coordinate: [ 44.912155   -33.4814       0.99117595]
# Well name 15-22 and its coordinate: [ 49.541763   -33.46518      0.99075574]
# Well name 15-23 and its coordinate: [ 54.171368  -33.44896     0.9903355]
# Well name 15-24 and its coordinate: [ 58.800972  -33.43274     0.9899154]
# Well name 16-1 and its coordinate: [-47.67996   -38.58378     0.9995798]
# Well name 16-2 and its coordinate: [-43.05035    -38.56756      0.99915963]
# Well name 16-3 and its coordinate: [-38.420746  -38.55134     0.9987394]
# Well name 16-4 and its coordinate: [-33.79114   -38.535122    0.9983192]
# Well name 16-5 and its coordinate: [-29.161535   -38.5189       0.99789906]
# Well name 16-6 and its coordinate: [-24.531929   -38.50268      0.99747884]
# Well name 16-7 and its coordinate: [-19.902323   -38.48646      0.99705863]
# Well name 16-8 and its coordinate: [-15.272717  -38.47024     0.9966385]
# Well name 16-9 and its coordinate: [-10.643112   -38.45402      0.99621826]
# Well name 16-10 and its coordinate: [ -6.0135064  -38.437805     0.99579805]
# Well name 16-11 and its coordinate: [ -1.3839006 -38.421585    0.9953779]
# Well name 16-12 and its coordinate: [  3.2457051 -38.405365    0.9949577]
# Well name 16-13 and its coordinate: [  7.875311  -38.389145    0.9945375]
# Well name 16-14 and its coordinate: [ 12.504916   -38.372925     0.99411726]
# Well name 16-15 and its coordinate: [ 17.134521  -38.356705    0.9936971]
# Well name 16-16 and its coordinate: [ 21.764128  -38.34049     0.9932769]
# Well name 16-17 and its coordinate: [ 26.393734  -38.32427     0.9928567]
# Well name 16-18 and its coordinate: [ 31.023338  -38.30805     0.9924365]
# Well name 16-19 and its coordinate: [ 35.652946  -38.29183     0.9920163]
# Well name 16-20 and its coordinate: [ 40.28255   -38.275608    0.9915961]
# Well name 16-21 and its coordinate: [ 44.912155   -38.259388     0.99117595]
# Well name 16-22 and its coordinate: [ 49.541763   -38.24317      0.99075574]
# Well name 16-23 and its coordinate: [ 54.171368  -38.22695     0.9903355]
# Well name 16-24 and its coordinate: [ 58.800972  -38.21073     0.9899154]

# %% [markdown]
# ## With fixit to correct for displacement

# %%
vectors, well_names, length, height, x_spacing = WellPlate.predict_well_coords(c_n, r_n, algorithm="Homography", algorithm_H="Levenberg-Marquardt", well_plate_req_coords=WellPlate.well_plate_req_coords
                            )

from DragonFlyWellPlateAutomation.devices.CoordinateTransforms import homography_fixit


### Get normalized length and height of axis
# Scaling factor of y and x 
transform = ((404.43636364-79.78181818)/72)
well_h= 4.5
print(transform)
#Pixels
well_h_pixels = (well_h * transform) 
#Points
p = 72/100
print(well_h_pixels)
#s
s = (well_h_pixels*p)**2
y_offset = (2/16)
x_offset = (2/24)
fov = 250*10**(-6) * 1024 #height
s = (fov*p)**2
    
axis = create_plot(xmin=-50-5, 
    xmax=60-5,
    ymin=-40-5,
    ymax= 34-5)

vectors = np.array(vectors, dtype=np.float32)
vectors = homography_fixit(( middwell - [4.8, 4.6, 0])[:2], vectors[-1], vectors.reshape(r_n, c_n, 3)).reshape(r_n * c_n, 3)

if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
for vector, wellname in zip(vectors,well_names):
    print("Well name {} and its coordinate: {}".format(wellname, vector))
    x,y,_ = vector
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    axis.text(x, y, wellname, ha='center', va='bottom',fontsize="xx-small")

plt.tight_layout()
plt.show()
# Out:
# 1. Getting all four corner wells coordinates as vectors
# 2. Computing coordinate space from well corners using Homography
# Learning the homography matrix using Levenberg-Marquardt to map from well plate row and column arrangement to xzy-stage coordinate space
# Saving all variables associated to the coordinate system.
# 4.509090909166667
# 20.29090909125
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.625
# Ymin -45.0 and Ymax 29.0
# Xmin -55.0 and Xmax 55.0
# Well name 1-1 and its coordinate: [-4.76799583e+01  3.30860901e+01  9.66441631e-03]
# Well name 1-2 and its coordinate: [-4.32503502e+01  3.31023102e+01  9.24426317e-03]
# Well name 1-3 and its coordinate: [-3.88207458e+01  3.31185303e+01  8.82405043e-03]
# Well name 1-4 and its coordinate: [-3.43911415e+01  3.31347504e+01  8.40383768e-03]
# Well name 1-5 and its coordinate: [-2.99615353e+01  3.31509666e+01  7.98368454e-03]
# Well name 16-12 and its coordinate: [ 1.04570513e+00 -4.27178650e+01  5.04231453e-03]
# Well name 16-13 and its coordinate: [ 5.47531090e+00 -4.27016449e+01  4.62210178e-03]
# Well name 16-14 and its coordinate: [ 9.90491619e+00 -4.26854248e+01  4.20188904e-03]
# Well name 16-15 and its coordinate: [ 1.43345215e+01 -4.26692047e+01  3.78173590e-03]
# Well name 16-16 and its coordinate: [ 1.87641277e+01 -4.26529884e+01  3.36152315e-03]
# Well name 16-17 and its coordinate: [ 2.31937340e+01 -4.26367683e+01  2.94131041e-03]
# Well name 16-18 and its coordinate: [ 2.76233383e+01 -4.26205482e+01  2.52115726e-03]
# Well name 16-19 and its coordinate: [ 3.20529465e+01 -4.26043282e+01  2.10094452e-03]
# Well name 16-20 and its coordinate: [ 3.64825508e+01 -4.25881081e+01  1.68073177e-03]
# Well name 16-21 and its coordinate: [ 4.09121552e+01 -4.25718880e+01  1.26057863e-03]
# Well name 16-22 and its coordinate: [ 4.53417633e+01 -4.25556717e+01  8.40365887e-04]
# Well name 16-23 and its coordinate: [ 4.97713676e+01 -4.25394516e+01  4.20153141e-04]
# Well name 16-24 and its coordinate: [ 54.20097198 -42.52323151   0.        ]

# %% [markdown]
# # Obtain Spacing of projective tra

# %%
axis = create_plot()

vectors = np.array(vectors, dtype=np.float32)
if len(vectors[0]) < 3:
    vectors = np.hstack((np.array(vectors, dtype=np.float32), np.zeros((len(vectors),1))))
    

for vector in np.hstack(vectors.reshape(r_n, c_n, 3).diagonal().reshape(3,16,1)):
    x,y,_ = vector
    
    axis.scatter(x,y, c="r", s=s*100, marker=",")
    
plt.show()
# Out:
# 4.509090909166667
# 20.29090909125
# x and y step: 4.583333333333333 and 4.5
# Ymin -38.0 and Ymax 34.0
# Xmin -50.0 and Xmax 60.0

# %%
out = np.diff(vectors.reshape(r_n, c_n, 3).diagonal(), axis=-1)
out
# Out:
# array([[ 4.6296043e+00,  4.6296043e+00,  4.6296082e+00,  4.6296043e+00,
#          4.6296062e+00,  4.6296043e+00,  4.6296062e+00,  4.6296062e+00,
#          4.6296053e+00,  4.6296058e+00,  4.6296058e+00,  4.6296053e+00,
#          4.6296062e+00,  4.6296053e+00,  4.6296062e+00],
#        [-4.7617722e+00, -4.7617712e+00, -4.7617722e+00, -4.7617712e+00,
#         -4.7617717e+00, -4.7617722e+00, -4.7617717e+00, -4.7617722e+00,
#         -4.7617712e+00, -4.7617722e+00, -4.7617722e+00, -4.7617722e+00,
#         -4.7617722e+00, -4.7617722e+00, -4.7617683e+00],
#        [-4.2009354e-04, -4.2033195e-04, -4.2009354e-04, -4.2033195e-04,
#         -4.2009354e-04, -4.2009354e-04, -4.2033195e-04, -4.2009354e-04,
#         -4.2033195e-04, -4.2009354e-04, -4.2009354e-04, -4.2033195e-04,
#         -4.2009354e-04, -4.2033195e-04, -4.2009354e-04]], dtype=float32)

# %%
x, y, z = out

# %%
abs(np.array([x[0], y[0], z[0]]))
# Out:
# array([4.6296043e+00, 4.7617722e+00, 4.2009354e-04], dtype=float32)
